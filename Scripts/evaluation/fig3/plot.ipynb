# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the font family
plt.rcParams['font.family'] = 'candara'

# Load the data for the first plot
csv_adult = r".\adult_labels.csv"
csv_child = r".\child_labels.csv"
df_adult = pd.read_csv(csv_adult)
df_child = pd.read_csv(csv_child)
# Create the first subplot
ax1 = plt.subplot(1, 2, 1)
df_adult.plot(kind='scatter',x='width',y='height', label='Adult',color = 'grey', ax=ax1) # scatter plot
df_child.plot(kind='scatter',x='width',y='height',color = 'black', ax=ax1 ,  label='Child') # scatter plot
plt.title("Adult and Child Distribution",fontdict={'fontweight':'bold','fontsize':15})
# Set the legend
plt.legend(loc='lower right', prop = {'weight':'bold'}, fontsize = 13)
# Load the data for the second plot
csv_detected = r".\detected.csv"
csv_miss = r".\not_detected.csv"
df_detected = pd.read_csv(csv_detected)
df_miss = pd.read_csv(csv_miss)

# Create the second subplot
ax2 = plt.subplot(1, 2, 2, sharex=ax1, sharey=ax1)
df_detected.plot(kind='scatter',x='width',y='height', label='Detected', color = 'grey', ax=ax2) # scatter plot
df_miss.plot(kind='scatter',x='width',y='height',color = 'black', ax=ax2, label='Undetected') # scatter plot

# Set the legend
plt.legend(loc='lower right', prop = {'weight':'bold'}, fontsize = 13)
plt.title("Deteced and Undeteced Distribution", fontdict={'fontweight':'bold','fontsize':15})

# Set the axis labels and tick labels
ax1.set_xlabel('Width', fontweight='bold', fontsize = 13)
ax1.set_ylabel('Height', fontweight='bold', fontsize = 13)
ax2.set_xlabel('Width', fontweight='bold', fontsize = 13)
ax2.set_ylabel('Height', fontweight='bold', fontsize = 13)

ax1.set_xticklabels(ax1.get_xticklabels(), fontdict = {'weight':'bold','fontsize':12})
ax1.set_yticklabels(ax1.get_yticklabels(), fontdict = {'weight':'bold','fontsize':12})
ax2.set_xticklabels(ax2.get_xticklabels(), fontdict = {'weight':'bold','fontsize':12})
ax2.set_yticklabels(ax2.get_yticklabels(), fontdict = {'weight':'bold','fontsize':12})

ax1.set_xticklabels(ax1.get_xticks(), fontdict = {'weight':'bold'})
ax1.set_yticklabels(ax1.get_yticks(), fontdict = {'weight':'bold'})
ax2.set_xticklabels(ax2.get_xticks(), fontdict = {'weight':'bold'})
ax2.set_yticklabels(ax2.get_yticks(), fontdict = {'weight':'bold'})

ax1.xaxis.set_major_formatter(plt.FormatStrFormatter("%d"))
ax1.yaxis.set_major_formatter(plt.FormatStrFormatter("%d"))
ax2.xaxis.set_major_formatter(plt.FormatStrFormatter("%d"))
ax2.yaxis.set_major_formatter(plt.FormatStrFormatter("%d"))

plt.gcf().set_size_inches(8,5)
# Show the merged plot
plt.savefig("Distribution Deteced and Age.png", dpi = 600)
# Out:
# C:\Users\22059\AppData\Local\Temp\ipykernel_29816\2544246877.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticklabels(), fontdict = {'weight':'bold','fontsize':12})
# C:\Users\22059\AppData\Local\Temp\ipykernel_29816\2544246877.py:41: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(ax1.get_yticklabels(), fontdict = {'weight':'bold','fontsize':12})
# C:\Users\22059\AppData\Local\Temp\ipykernel_29816\2544246877.py:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(ax2.get_xticklabels(), fontdict = {'weight':'bold','fontsize':12})
# C:\Users\22059\AppData\Local\Temp\ipykernel_29816\2544246877.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticks(), fontdict = {'weight':'bold'})
# C:\Users\22059\AppData\Local\Temp\ipykernel_29816\2544246877.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(ax1.get_yticks(), fontdict = {'weight':'bold'})
# C:\Users\22059\AppData\Local\Temp\ipykernel_29816\2544246877.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(ax2.get_xticks(), fontdict = {'weight':'bold'})
# C:\Users\22059\AppData\Local\Temp\ipykernel_29816\2544246877.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels(ax2.get_yticks(), fontdict = {'weight':'bold'})
